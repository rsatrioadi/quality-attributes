# %% [markdown]
# # Load knowledge to neo4j

# %%
# %pip install --upgrade py2neo
# Out:
# Collecting py2neo
#   Downloading py2neo-2021.2.3-py2.py3-none-any.whl (177 kB)
# Collecting interchange~=2021.0.4
#   Downloading interchange-2021.0.4-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: packaging in c:\users\20215365\applications\miniconda3\lib\site-packages (from py2neo) (21.3)
# Requirement already satisfied: pygments>=2.0.0 in c:\users\20215365\applications\miniconda3\lib\site-packages (from py2neo) (2.10.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\20215365\applications\miniconda3\lib\site-packages (from py2neo) (1.16.0)
# Requirement already satisfied: certifi in c:\users\20215365\applications\miniconda3\lib\site-packages (from py2neo) (2022.9.14)
# Collecting monotonic
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting pansi>=2020.7.3
#   Downloading pansi-2020.7.3-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: urllib3 in c:\users\20215365\applications\miniconda3\lib\site-packages (from py2neo) (1.26.7)
# Requirement already satisfied: pytz in c:\users\20215365\applications\miniconda3\lib\site-packages (from interchange~=2021.0.4->py2neo) (2019.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\20215365\applications\miniconda3\lib\site-packages (from packaging->py2neo) (3.0.6)
# Installing collected packages: pansi, monotonic, interchange, py2neo
# Successfully installed interchange-2021.0.4 monotonic-1.6 pansi-2020.7.3 py2neo-2021.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from py2neo import Graph
from py2neo import Node, Relationship
import csv
import json

def when(condition, true, false):
  return true if condition else false

# %%
graph = Graph('bolt://localhost:7687', auth=('neo4j','200Watt!'))

# %%
# graph.delete_all()

# %%
def capsnake(s: str):
  return "".join([c if c.isalnum() else "_" for c in s]).upper()

def rel(e, nodes):
  s = nodes[e['source']]
  t = nodes[e['target']]
  return Relationship(s, capsnake(e['interaction']), t)

# %%
with open('metamodel/maintainability-0-nodes.csv') as csv_file:
  csv_reader = csv.DictReader(csv_file)
  mm_nodes = {
    row['id']: Node(row['type'], name=row['name'])
    for row in csv_reader
  }

with open('metamodel/maintainability-0-edges.csv') as csv_file:
  csv_reader = csv.DictReader(csv_file)
  mm_edges = [rel(row, mm_nodes) for row in csv_reader]

print(mm_edges[123])
# Out:
# (Intercepting Filter)-[:EMPLOYS {}]->(Split module)

# %%
tx = graph.begin()

for node in mm_nodes.values():
  tx.create(node)

for edge in mm_edges:
  tx.create(edge)

graph.commit(tx)

# %%
prj = Node("Project", name='JHotDraw', version='5.1')
pkgs = dict()
prj_nodes = dict()
prj_edges = []
containment = []

with open('cases/JHotDraw-v5.1/facts/impl-time/jhotdraw-nodes.csv') as csv_file:
  csv_reader = csv.DictReader(csv_file)
  for row in csv_reader:
    if row['package'] not in pkgs:
      row['package'] = Node('Component', name=row['package'], type='PKG')
    pkg = row['package']
    clss = Node(row['type'], name=row['name'], fullname=row['id'])
    prj_nodes[row['id']] = clss
    containment.append(Relationship(pkg, "CONTAINS", clss))
    containment.append(Relationship(clss, "BELONGS_TO", prj))
  
print(containment[0], containment[1])

with open('cases/JHotDraw-v5.1/facts/impl-time/jhotdraw-edges.csv') as csv_file:
  csv_reader = csv.DictReader(csv_file)
  for row in csv_reader:
    relt = rel(row, prj_nodes)
    relt['weight'] = row['weight']
    prj_edges.append(relt)

print(prj_edges[123])
# Out:
# (CH.ifa.draw.applet)-[:CONTAINS {}]->(DrawApplet) (DrawApplet)-[:BELONGS_TO {}]->(JHotDraw)
# (PolygonHandle)-[:SPECIALIZES {weight: '1'}]->(AbstractHandle)

# %%
tx = graph.begin()

tx.create(prj)

for node in pkgs.values():
  tx.create(node)

for node in prj_nodes.values():
  tx.create(node)

for edge in containment:
  tx.create(edge)

for edge in prj_edges:
  tx.create(edge)

graph.commit(tx)

# %%
adapter_pattern = graph.nodes.match('Pattern', name='Adapter').first()

print(adapter_pattern)

with open('metamodel/adapter-pattern-0-nodes.csv') as csv_file:
  csv_reader = csv.DictReader(csv_file)
  adp_nodes = { row['id']:  when(graph.nodes.match(row['type'], name=row['name']),
                                true = graph.nodes.match(row['type'], name=row['name']).first(),
                                false = Node(row['type'], name=row['name']))
    for row in csv_reader
  }

with open('metamodel/adapter-pattern-0-edges.csv') as csv_file:
  csv_reader = csv.DictReader(csv_file)
  adp_edges = [rel(row, adp_nodes) for row in csv_reader]

print(adp_nodes, adp_edges)
# Out:
# (_388:Pattern {name: 'Adapter'})
# {'n0': Node('Role', name='Client'), 'n1': Node('Pattern', name='Adapter'), 'n2': Node('Role', name='Target'), 'n3': Node('Role', name='Adapter'), 'n4': Node('Role', name='Adaptee')} [INVOLVES(Node('Pattern', name='Adapter'), Node('Role', name='Client')), INVOLVES(Node('Pattern', name='Adapter'), Node('Role', name='Target')), INVOLVES(Node('Pattern', name='Adapter'), Node('Role', name='Adapter')), INVOLVES(Node('Pattern', name='Adapter'), Node('Role', name='Adaptee'))]

# %%
tx = graph.begin()

for node in adp_nodes.values():
  tx.create(node)

for edge in adp_edges:
  tx.create(edge)

graph.commit(tx)

# %%
with open('cases/JHotDraw-v5.1/patterns/ptidej-jhotdraw-v5.1.json') as json_file:
  data = json.load(json_file)

# %% [markdown]
# Reminder: flattening list in Python:
#
# ```python
# flat_list = [
#   item
#   for sublist in regular_list
#   for item in sublist
# ]
# ```

# %%
pattern_instances = [
  (microArchs['_name'], [(x,y) for x,sublist in [
    (role.title(), [actor['entity'] for actor in actors[role]])
    for actors in instance['roles'].values() 
    for role in actors
  ] for y in sublist])
  for microArchs in data['designPattern'] 
  for instance in microArchs['microArchitectures']['microArchitecture']
]

pattern_instances
# Out:
# [('Adapter',
#   [('Client', 'CH.ifa.draw.standard.StandardDrawingView'),
#    ('Client', 'CH.ifa.draw.standard.HandleTracker'),
#    ('Target', 'CH.ifa.draw.framework.Handle'),
#    ('Adapter', 'CH.ifa.draw.standard.ChangeConnectionEndHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.ChangeConnectionStartHandle'),
#    ('Adapter', 'CH.ifa.draw.figures.ElbowHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.LocatorHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.ConnectionHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.EastHandle'),
#    ('Adapter', 'CH.ifa.draw.figures.FontSizeHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.NorthEastHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.NorthHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.NorthWestHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.NullHandle'),
#    ('Adapter', 'CH.ifa.draw.figures.GroupHandle'),
#    ('Adapter', 'CH.ifa.draw.figures.PolyLineHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.SouthEastHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.SouthHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.SouthWestHandle'),
#    ('Adapter', 'CH.ifa.draw.standard.WestHandle'),
#    ('Adapter', 'CH.ifa.draw.contrib.PolygonHandle'),
#    ('Adapter', 'CH.ifa.draw.contrib.PolygonScaleHandle'),
#    ('Adapter', 'CH.ifa.draw.figures.RadiusHandle'),
#    ('Adapter', 'CH.ifa.draw.contrib.TriangleRotationHandle'),
#    ('Adaptee', 'CH.ifa.draw.framework.Figure'),
#    ('Adaptee', 'CH.ifa.draw.framework.ConnectionFigure'),
#    ('Adaptee', 'CH.ifa.draw.figures.LineConnection'),
#    ('Adaptee', 'CH.ifa.draw.framework.Locator'),
#    ('Adaptee', 'CH.ifa.draw.figures.TextFigure'),
#    ('Adaptee', 'CH.ifa.draw.figures.PolyLineFigure'),
#    ('Adaptee', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Adaptee', 'CH.ifa.draw.figures.RoundRectangleFigure')]),
#  ('Command',
#   [('Client', 'CH.ifa.draw.application.DrawApplication'),
#    ('Client', 'CH.ifa.draw.applet.DrawApplet'),
#    ('Client', 'CH.ifa.draw.standard.StandardDrawingView'),
#    ('Client', 'CH.ifa.draw.samples.javadraw.JavaDrawApp'),
#    ('Invoker', 'CH.ifa.draw.standard.StandardDrawingView'),
#    ('Invoker', 'CH.ifa.draw.util.CommandButton'),
#    ('Invoker', 'CH.ifa.draw.util.CommandChoice'),
#    ('Invoker', 'CH.ifa.draw.util.CommandMenu'),
#    ('Command', 'CH.ifa.draw.util.Command'),
#    ('Concretecommand', 'CH.ifa.draw.standard.AlignCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.BringToFrontCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.ChangeAttributeCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.CopyCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.CutCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.DeleteCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.DuplicateCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.PasteCommand'),
#    ('Concretecommand', 'CH.ifa.draw.figures.GroupCommand'),
#    ('Concretecommand', 'CH.ifa.draw.figures.InsertImageCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.SendToBackCommand'),
#    ('Concretecommand', 'CH.ifa.draw.standard.ToggleGridCommand'),
#    ('Concretecommand', 'CH.ifa.draw.figures.UngroupCommand'),
#    ('Receiver', 'CH.ifa.draw.framework.Figure'),
#    ('Receiver', 'CH.ifa.draw.framework.FigureSelection'),
#    ('Receiver', 'CH.ifa.draw.framework.Drawing'),
#    ('Receiver', 'CH.ifa.draw.framework.DrawingView')]),
#  ('Composite',
#   [('Client', 'CH.ifa.draw.figures.GroupCommand'),
#    ('Client', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Client', 'CH.ifa.draw.samples.pert.PertFigureCreationTool'),
#    ('Client', 'CH.ifa.draw.applet.DrawApplet'),
#    ('Client', 'CH.ifa.draw.application.DrawApplication'),
#    ('Client', 'CH.ifa.draw.samples.javadraw.JavaDrawViewer'),
#    ('Client', 'CH.ifa.draw.samples.javadraw.JavaDrawApp'),
#    ('Client', 'CH.ifa.draw.samples.javadraw.JavaDrawApplet'),
#    ('Component', 'CH.ifa.draw.framework.Figure'),
#    ('Composite', 'CH.ifa.draw.standard.CompositeFigure'),
#    ('Composite', 'CH.ifa.draw.figures.GroupFigure'),
#    ('Composite', 'CH.ifa.draw.samples.pert.PertFigure'),
#    ('Composite', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Composite', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Leaf', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Leaf', 'CH.ifa.draw.figures.ImageFigure'),
#    ('Leaf', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Leaf', 'CH.ifa.draw.figures.RectangleFigure'),
#    ('Leaf', 'CH.ifa.draw.contrib.DiamondFigure'),
#    ('Leaf', 'CH.ifa.draw.contrib.TriangleFigure'),
#    ('Leaf', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Leaf', 'CH.ifa.draw.figures.TextFigure'),
#    ('Leaf', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Leaf', 'CH.ifa.draw.figures.NumberTextFigure'),
#    ('Leaf', 'CH.ifa.draw.figures.GroupFigure'),
#    ('Leaf', 'CH.ifa.draw.samples.pert.PertFigure'),
#    ('Leaf', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Leaf', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Leaf', 'CH.ifa.draw.samples.javadraw.AnimationDecorator'),
#    ('Leaf', 'CH.ifa.draw.figures.BorderDecorator'),
#    ('Leaf', 'CH.ifa.draw.figures.PolyLineFigure'),
#    ('Leaf', 'CH.ifa.draw.figures.LineConnection'),
#    ('Leaf', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Leaf', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Leaf', 'CH.ifa.draw.figures.LineFigure'),
#    ('Leaf', 'CH.ifa.draw.figures.LineConnection'),
#    ('Leaf', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Leaf', 'CH.ifa.draw.samples.pert.PertDependency')]),
#  ('Decorator',
#   [('Component', 'CH.ifa.draw.framework.Figure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.ImageFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.RectangleFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.contrib.DiamondFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.contrib.TriangleFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.TextFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.NumberTextFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.GroupFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.samples.pert.PertFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Concretecomponent', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.PolyLineFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concretecomponent', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.LineFigure'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concretecomponent', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concretecomponent', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Decorator', 'CH.ifa.draw.standard.DecoratorFigure'),
#    ('Concretedecorator', 'CH.ifa.draw.samples.javadraw.AnimationDecorator'),
#    ('Concretedecorator', 'CH.ifa.draw.figures.BorderDecorator')]),
#  ('Factory Method',
#   [('Product', 'CH.ifa.draw.framework.Connector'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.ChopBoxConnector'),
#    ('Concreteproduct', 'CH.ifa.draw.figures.ChopEllipseConnector'),
#    ('Concreteproduct', 'CH.ifa.draw.contrib.ChopPolygonConnector'),
#    ('Concreteproduct', 'CH.ifa.draw.figures.PolyLineConnector'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.LocatorConnector'),
#    ('Concreteproduct', 'CH.ifa.draw.figures.ShortestDistanceConnector'),
#    ('Creator', 'CH.ifa.draw.framework.Figure'),
#    ('Concretecreator', 'CH.ifa.draw.standard.AbstractFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Concretecreator', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.PolyLineFigure')]),
#  ('Factory Method',
#   [('Product', 'CH.ifa.draw.framework.Handle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.EastHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.NorthHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.NorthEastHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.NorthWestHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.SouthHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.SouthEastHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.SouthWestHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.WestHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.contrib.PolygonHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.contrib.PolygonScaleHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.contrib.TriangleRotationHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.NullHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.figures.FontSizeHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.ConnectionHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.figures.GroupHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.ChangeConnectionStartHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.figures.PolyLineHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.ChangeConnectionEndHandle'),
#    ('Concreteproduct', 'CH.ifa.draw.figures.ElbowHandle'),
#    ('Creator', 'CH.ifa.draw.framework.Figure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.ImageFigure'),
#    ('Concretecreator', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.RectangleFigure'),
#    ('Concretecreator', 'CH.ifa.draw.contrib.DiamondFigure'),
#    ('Concretecreator', 'CH.ifa.draw.contrib.TriangleFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.TextFigure'),
#    ('Concretecreator', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.NumberTextFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.GroupFigure'),
#    ('Concretecreator', 'CH.ifa.draw.samples.pert.PertFigure'),
#    ('Concretecreator', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Concretecreator', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Concretecreator', 'CH.ifa.draw.samples.javadraw.AnimationDecorator'),
#    ('Concretecreator', 'CH.ifa.draw.figures.BorderDecorator'),
#    ('Concretecreator', 'CH.ifa.draw.figures.PolyLineFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concretecreator', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concretecreator', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Concretecreator', 'CH.ifa.draw.figures.LineFigure'),
#    ('Concretecreator', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concretecreator', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concretecreator', 'CH.ifa.draw.samples.pert.PertDependency')]),
#  ('Factory Method',
#   [('Product', 'CH.ifa.draw.framework.Tool'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.HandleTracker'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.DragTracker'),
#    ('Concreteproduct', 'CH.ifa.draw.standard.SelectAreaTracker'),
#    ('Concretecreator', 'CH.ifa.draw.standard.SelectionTool')]),
#  ('Null Object', [('Nullobject', 'CH.ifa.draw.standard.NullHandle')]),
#  ('Observer',
#   [('Subject', 'CH.ifa.draw.framework.Figure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.ImageFigure'),
#    ('Concretesubject', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.RectangleFigure'),
#    ('Concretesubject', 'CH.ifa.draw.contrib.DiamondFigure'),
#    ('Concretesubject', 'CH.ifa.draw.contrib.TriangleFigure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.TextFigure'),
#    ('Concretesubject', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.NumberTextFigure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.GroupFigure'),
#    ('Concretesubject', 'CH.ifa.draw.samples.pert.PertFigure'),
#    ('Concretesubject', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Concretesubject', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Concretesubject', 'CH.ifa.draw.samples.javadraw.AnimationDecorator'),
#    ('Concretesubject', 'CH.ifa.draw.figures.BorderDecorator'),
#    ('Concretesubject', 'CH.ifa.draw.figures.PolyLineFigure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concretesubject', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concretesubject', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Concretesubject', 'CH.ifa.draw.figures.LineFigure'),
#    ('Concretesubject', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concretesubject', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concretesubject', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Observer', 'CH.ifa.draw.framework.FigureChangeListener'),
#    ('Concreteobserver', 'CH.ifa.draw.figures.GroupFigure'),
#    ('Concreteobserver', 'CH.ifa.draw.samples.pert.PertFigure'),
#    ('Concreteobserver', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Concreteobserver', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Concreteobserver', 'CH.ifa.draw.samples.javadraw.AnimationDecorator'),
#    ('Concreteobserver', 'CH.ifa.draw.figures.BorderDecorator'),
#    ('Concreteobserver', 'CH.ifa.draw.standard.FigureChangeEventMulticaster'),
#    ('Concreteobserver', 'CH.ifa.draw.figures.TextFigure'),
#    ('Concreteobserver', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Concreteobserver', 'CH.ifa.draw.figures.NumberTextFigure'),
#    ('Concreteobserver', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concreteobserver', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concreteobserver', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Concreteobserver', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Concreteobserver', 'CH.ifa.draw.samples.javadraw.BouncingDrawing')]),
#  ('Observer',
#   [('Subject', 'CH.ifa.draw.framework.Drawing'),
#    ('Concretesubject', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Concretesubject', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Observer', 'CH.ifa.draw.framework.DrawingChangeListener'),
#    ('Concreteobserver', 'CH.ifa.draw.standard.StandardDrawingView')]),
#  ('Observer',
#   [('Subject', 'CH.ifa.draw.framework.Connector'),
#    ('Concretesubject', 'CH.ifa.draw.standard.ChopBoxConnector'),
#    ('Concretesubject', 'CH.ifa.draw.standard.LocatorConnector'),
#    ('Concretesubject', 'CH.ifa.draw.figures.ShortestDistanceConnector'),
#    ('Observer', 'CH.ifa.draw.framework.ConnectionFigure'),
#    ('Concreteobserver', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concreteobserver', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concreteobserver', 'CH.ifa.draw.samples.pert.PertDependency')]),
#  ('Prototype',
#   [('Client', 'CH.ifa.draw.standard.ConnectionHandle'),
#    ('Client', 'CH.ifa.draw.standard.ConnectionTool'),
#    ('Prototype', 'CH.ifa.draw.framework.ConnectionFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concreteprototype', 'CH.ifa.draw.samples.pert.PertDependency')]),
#  ('Prototype',
#   [('Client', 'CH.ifa.draw.standard.CreationTool'),
#    ('Prototype', 'CH.ifa.draw.framework.Figure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.ImageFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.RectangleFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.contrib.DiamondFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.contrib.TriangleFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.TextFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.NumberTextFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.GroupFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.samples.pert.PertFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Concreteprototype', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Concreteprototype', 'CH.ifa.draw.samples.javadraw.AnimationDecorator'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.BorderDecorator'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.PolyLineFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concreteprototype', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.LineFigure'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concreteprototype', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concreteprototype', 'CH.ifa.draw.samples.pert.PertDependency')]),
#  ('Singleton', [('Singleton', 'CH.ifa.draw.util.Clipboard')]),
#  ('Singleton', [('Singleton', 'CH.ifa.draw.util.Iconkit')]),
#  ('State',
#   [('Context', 'CH.ifa.draw.standard.StandardDrawingView'),
#    ('State', 'CH.ifa.draw.framework.Tool'),
#    ('Concretestate', 'CH.ifa.draw.standard.AbstractTool'),
#    ('Concretestate', 'CH.ifa.draw.figures.BorderTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.ConnectionTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.CreationTool'),
#    ('Concretestate', 'CH.ifa.draw.samples.pert.PertFigureCreationTool'),
#    ('Concretestate', 'CH.ifa.draw.figures.TextTool'),
#    ('Concretestate', 'CH.ifa.draw.figures.ConnectedTextTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.DragTracker'),
#    ('Concretestate', 'CH.ifa.draw.samples.javadraw.FollowURLTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.HandleTracker'),
#    ('Concretestate', 'CH.ifa.draw.contrib.PolygonTool'),
#    ('Concretestate', 'CH.ifa.draw.figures.ScribbleTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.SelectAreaTracker'),
#    ('Concretestate', 'CH.ifa.draw.standard.SelectionTool'),
#    ('Concretestate', 'CH.ifa.draw.samples.javadraw.MySelectionTool'),
#    ('Concretestate', 'CH.ifa.draw.samples.javadraw.URLTool')]),
#  ('State',
#   [('Context', 'CH.ifa.draw.standard.SelectionTool'),
#    ('State', 'CH.ifa.draw.framework.Tool'),
#    ('Concretestate', 'CH.ifa.draw.standard.DragTracker'),
#    ('Concretestate', 'CH.ifa.draw.standard.HandleTracker'),
#    ('Concretestate', 'CH.ifa.draw.standard.SelectAreaTracker')]),
#  ('State',
#   [('Context', 'CH.ifa.draw.framework.DrawingView'),
#    ('State', 'CH.ifa.draw.framework.Tool'),
#    ('Concretestate', 'CH.ifa.draw.standard.AbstractTool'),
#    ('Concretestate', 'CH.ifa.draw.figures.BorderTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.ConnectionTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.CreationTool'),
#    ('Concretestate', 'CH.ifa.draw.samples.pert.PertFigureCreationTool'),
#    ('Concretestate', 'CH.ifa.draw.figures.TextTool'),
#    ('Concretestate', 'CH.ifa.draw.figures.ConnectedTextTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.DragTracker'),
#    ('Concretestate', 'CH.ifa.draw.samples.javadraw.FollowURLTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.HandleTracker'),
#    ('Concretestate', 'CH.ifa.draw.contrib.PolygonTool'),
#    ('Concretestate', 'CH.ifa.draw.figures.ScribbleTool'),
#    ('Concretestate', 'CH.ifa.draw.standard.SelectAreaTracker'),
#    ('Concretestate', 'CH.ifa.draw.standard.SelectionTool'),
#    ('Concretestate', 'CH.ifa.draw.samples.javadraw.MySelectionTool'),
#    ('Concretestate', 'CH.ifa.draw.samples.javadraw.URLTool')]),
#  ('Strategy',
#   [('Context', 'CH.ifa.draw.figures.LineConnection'),
#    ('Context', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Context', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Context', 'CH.ifa.draw.figures.PolyLineFigure'),
#    ('Context', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Context', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Context', 'CH.ifa.draw.standard.AbstractFigure'),
#    ('Context', 'CH.ifa.draw.standard.DecoratorFigure'),
#    ('Context', 'CH.ifa.draw.framework.ConnectionFigure'),
#    ('Context', 'CH.ifa.draw.standard.ConnectionTool'),
#    ('Context', 'CH.ifa.draw.standard.ChangeConnectionHandle'),
#    ('Context', 'CH.ifa.draw.standard.ConnectionHandle'),
#    ('Strategy', 'CH.ifa.draw.framework.Connector'),
#    ('Concretestrategy', 'CH.ifa.draw.standard.ChopBoxConnector'),
#    ('Concretestrategy', 'CH.ifa.draw.figures.ChopEllipseConnector'),
#    ('Concretestrategy', 'CH.ifa.draw.contrib.ChopPolygonConnector'),
#    ('Concretestrategy', 'CH.ifa.draw.figures.PolyLineConnector'),
#    ('Concretestrategy', 'CH.ifa.draw.standard.LocatorConnector'),
#    ('Concretestrategy', 'CH.ifa.draw.figures.ShortestDistanceConnector')]),
#  ('Strategy',
#   [('Context', 'CH.ifa.draw.standard.StandardDrawingView'),
#    ('Strategy', 'CH.ifa.draw.framework.Painter'),
#    ('Concretestrategy', 'CH.ifa.draw.standard.BufferedUpdateStrategy'),
#    ('Concretestrategy', 'CH.ifa.draw.samples.javadraw.PatternPainter'),
#    ('Concretestrategy', 'CH.ifa.draw.standard.SimpleUpdateStrategy')]),
#  ('Strategy',
#   [('Context', 'CH.ifa.draw.contrib.PolygonHandle'),
#    ('Context', 'CH.ifa.draw.figures.TextFigure'),
#    ('Context', 'CH.ifa.draw.standard.LocatorConnector'),
#    ('Context', 'CH.ifa.draw.standard.LocatorHandle'),
#    ('Strategy', 'CH.ifa.draw.framework.Locator'),
#    ('Concretestrategy', 'CH.ifa.draw.figures.ElbowTextLocator'),
#    ('Concretestrategy', 'CH.ifa.draw.standard.OffsetLocator'),
#    ('Concretestrategy', 'CH.ifa.draw.figures.PolyLineLocator'),
#    ('Concretestrategy', 'CH.ifa.draw.standard.RelativeLocator')]),
#  ('Strategy',
#   [('Context', 'CH.ifa.draw.standard.StandardDrawingView'),
#    ('Strategy', 'CH.ifa.draw.framework.PointConstrainer'),
#    ('Concretestrategy', 'CH.ifa.draw.standard.GridConstrainer')]),
#  ('Template Method',
#   [('Abstractclass', 'CH.ifa.draw.standard.AbstractFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.ImageFigure'),
#    ('Concreteclass', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.RectangleFigure'),
#    ('Concreteclass', 'CH.ifa.draw.contrib.DiamondFigure'),
#    ('Concreteclass', 'CH.ifa.draw.contrib.TriangleFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.TextFigure'),
#    ('Concreteclass', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.NumberTextFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.GroupFigure'),
#    ('Concreteclass', 'CH.ifa.draw.samples.pert.PertFigure'),
#    ('Concreteclass', 'CH.ifa.draw.standard.StandardDrawing'),
#    ('Concreteclass', 'CH.ifa.draw.samples.javadraw.BouncingDrawing'),
#    ('Concreteclass', 'CH.ifa.draw.samples.javadraw.AnimationDecorator'),
#    ('Concreteclass', 'CH.ifa.draw.figures.BorderDecorator'),
#    ('Concreteclass', 'CH.ifa.draw.figures.PolyLineFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concreteclass', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concreteclass', 'CH.ifa.draw.samples.pert.PertDependency'),
#    ('Concreteclass', 'CH.ifa.draw.figures.LineFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.LineConnection'),
#    ('Concreteclass', 'CH.ifa.draw.figures.ElbowConnection'),
#    ('Concreteclass', 'CH.ifa.draw.samples.pert.PertDependency')]),
#  ('Template Method',
#   [('Abstractclass', 'CH.ifa.draw.figures.AttributeFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.EllipseFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.ImageFigure'),
#    ('Concreteclass', 'CH.ifa.draw.contrib.PolygonFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.RectangleFigure'),
#    ('Concreteclass', 'CH.ifa.draw.contrib.DiamondFigure'),
#    ('Concreteclass', 'CH.ifa.draw.contrib.TriangleFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.RoundRectangleFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.TextFigure'),
#    ('Concreteclass', 'CH.ifa.draw.samples.net.NodeFigure'),
#    ('Concreteclass', 'CH.ifa.draw.figures.NumberTextFigure')])]

# %%
pattern_names = [
  # 'Adapter',
  'Strategy',
]

for p,i in pattern_instances:
  if p in pattern_names:
    roles = set(r for r,_ in i)
    for role in roles:
      if not graph.nodes.match('Role', name=role) and graph.nodes.match('Pattern', name=p):
        role_node = Node('Role', name=role)
        pat_node = graph.nodes.match('Pattern', name=p).first()
        role_edge = Relationship(pat_node, "INVOLVES", role_node)
        tx = graph.begin()
        tx.create(role_node)
        tx.create(role_edge)
        graph.commit(tx)

# %%
pi_nodes = []
pi_edges = []
for p,i in pattern_instances:
  if p in pattern_names:
    adp = graph.nodes.match('Pattern', name=p).first()
    pi = Node('PatternInstance')
    relpi = Relationship(pi, "INSTANCE_OF", adp)
    pi_nodes.append(pi)
    pi_edges.append(relpi)
    for role, clss in i:
      role_node = graph.nodes.match('Role', name=role).first()
      struct_node = graph.nodes.match('Structure', fullname=clss).first()
      pi_edges.append(Relationship(struct_node, "ACTS_AS", role_node))
      pi_edges.append(Relationship(pi, "INVOLVES", struct_node))

pi_nodes, pi_edges
# Out:
# ([Node('PatternInstance'),
#   Node('PatternInstance'),
#   Node('PatternInstance'),
#   Node('PatternInstance')],
#  [INSTANCE_OF(Node('PatternInstance'), Node('Pattern', name='Strategy')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.LineConnection', name='LineConnection'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.LineConnection', name='LineConnection')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.contrib.PolygonFigure', name='PolygonFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.contrib.PolygonFigure', name='PolygonFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.EllipseFigure', name='EllipseFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.EllipseFigure', name='EllipseFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.PolyLineFigure', name='PolyLineFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.PolyLineFigure', name='PolyLineFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.RoundRectangleFigure', name='RoundRectangleFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.RoundRectangleFigure', name='RoundRectangleFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.samples.net.NodeFigure', name='NodeFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.samples.net.NodeFigure', name='NodeFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.AbstractFigure', name='AbstractFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.AbstractFigure', name='AbstractFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.DecoratorFigure', name='DecoratorFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.DecoratorFigure', name='DecoratorFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.framework.ConnectionFigure', name='ConnectionFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.framework.ConnectionFigure', name='ConnectionFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.ConnectionTool', name='ConnectionTool'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.ConnectionTool', name='ConnectionTool')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.ChangeConnectionHandle', name='ChangeConnectionHandle'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.ChangeConnectionHandle', name='ChangeConnectionHandle')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.ConnectionHandle', name='ConnectionHandle'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.ConnectionHandle', name='ConnectionHandle')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.framework.Connector', name='Connector'), Node('Role', name='Strategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.framework.Connector', name='Connector')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.ChopBoxConnector', name='ChopBoxConnector'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.ChopBoxConnector', name='ChopBoxConnector')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.ChopEllipseConnector', name='ChopEllipseConnector'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.ChopEllipseConnector', name='ChopEllipseConnector')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.contrib.ChopPolygonConnector', name='ChopPolygonConnector'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.contrib.ChopPolygonConnector', name='ChopPolygonConnector')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.PolyLineConnector', name='PolyLineConnector'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.PolyLineConnector', name='PolyLineConnector')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.LocatorConnector', name='LocatorConnector'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.LocatorConnector', name='LocatorConnector')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.ShortestDistanceConnector', name='ShortestDistanceConnector'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.ShortestDistanceConnector', name='ShortestDistanceConnector')),
#   INSTANCE_OF(Node('PatternInstance'), Node('Pattern', name='Strategy')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.StandardDrawingView', name='StandardDrawingView'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.StandardDrawingView', name='StandardDrawingView')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.framework.Painter', name='Painter'), Node('Role', name='Strategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.framework.Painter', name='Painter')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.BufferedUpdateStrategy', name='BufferedUpdateStrategy'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.BufferedUpdateStrategy', name='BufferedUpdateStrategy')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.samples.javadraw.PatternPainter', name='PatternPainter'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.samples.javadraw.PatternPainter', name='PatternPainter')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.SimpleUpdateStrategy', name='SimpleUpdateStrategy'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.SimpleUpdateStrategy', name='SimpleUpdateStrategy')),
#   INSTANCE_OF(Node('PatternInstance'), Node('Pattern', name='Strategy')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.contrib.PolygonHandle', name='PolygonHandle'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.contrib.PolygonHandle', name='PolygonHandle')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.TextFigure', name='TextFigure'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.TextFigure', name='TextFigure')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.LocatorConnector', name='LocatorConnector'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.LocatorConnector', name='LocatorConnector')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.LocatorHandle', name='LocatorHandle'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.LocatorHandle', name='LocatorHandle')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.framework.Locator', name='Locator'), Node('Role', name='Strategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.framework.Locator', name='Locator')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.ElbowTextLocator', name='ElbowTextLocator'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.ElbowTextLocator', name='ElbowTextLocator')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.OffsetLocator', name='OffsetLocator'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.OffsetLocator', name='OffsetLocator')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.figures.PolyLineLocator', name='PolyLineLocator'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.figures.PolyLineLocator', name='PolyLineLocator')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.RelativeLocator', name='RelativeLocator'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.RelativeLocator', name='RelativeLocator')),
#   INSTANCE_OF(Node('PatternInstance'), Node('Pattern', name='Strategy')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.StandardDrawingView', name='StandardDrawingView'), Node('Role', name='Context')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.StandardDrawingView', name='StandardDrawingView')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.framework.PointConstrainer', name='PointConstrainer'), Node('Role', name='Strategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.framework.PointConstrainer', name='PointConstrainer')),
#   ACTS_AS(Node('Structure', fullname='CH.ifa.draw.standard.GridConstrainer', name='GridConstrainer'), Node('Role', name='Concretestrategy')),
#   INVOLVES(Node('PatternInstance'), Node('Structure', fullname='CH.ifa.draw.standard.GridConstrainer', name='GridConstrainer'))])

# %%
tx = graph.begin()

for node in pi_nodes + pi_edges:
  tx.create(node)

graph.commit(tx)
